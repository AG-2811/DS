# %%
pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r"C:\Users\anjna\OneDrive\Desktop\002irm_com_fea_dsk_01.jpg")
arr
# Out:
# array([[[53, 44, 47],
#         [53, 44, 47],
#         [53, 44, 47],
#         ...,
#         [55, 46, 49],
#         [55, 46, 49],
#         [55, 46, 49]],
#
#        [[53, 44, 47],
#         [53, 44, 47],
#         [53, 44, 47],
#         ...,
#         [55, 46, 49],
#         [55, 46, 49],
#         [55, 46, 49]],
#
#        [[53, 44, 47],
#         [53, 44, 47],
#         [53, 44, 47],
#         ...,
#         [55, 46, 49],
#         [55, 46, 49],
#         [55, 46, 49]],
#
#        ...,
#
#        [[90, 96, 94],
#         [90, 96, 94],
#         [90, 96, 94],
#         ...,
#         [79, 85, 83],
#         [78, 84, 82],
#         [77, 83, 81]],
#
#        [[90, 96, 94],
#         [90, 96, 94],
#         [90, 96, 94],
#         ...,
#         [80, 86, 84],
#         [79, 85, 83],
#         [78, 84, 82]],
#
#        [[91, 97, 95],
#         [91, 97, 95],
#         [91, 97, 95],
#         ...,
#         [81, 85, 84],
#         [80, 86, 84],
#         [80, 86, 84]]], dtype=uint8)

# %%
a_arr = arr.copy()
plt.imshow(a_arr)

# %%
a_arr.shape
# Out:
# (700, 1920, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
while True:
    
    a = np.random.randint(0,255,(5,5,3))
    plt.imshow(a)
    plt.show()
    time.sleep(1)
    display(clear = True)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[131, 180, 204],
#         [ 34,  11, 180],
#         [197, 139, 199],
#         [ 74, 112, 189]],
#
#        [[ 58, 101,  85],
#         [159, 253, 188],
#         [233, 167,  35],
#         [153,  61,  32]],
#
#        [[169, 136,  91],
#         [252, 161, 104],
#         [ 19, 211, 163],
#         [254, 163, 194]],
#
#        [[ 85, 163,  54],
#         [ 95, 234, 125],
#         [ 61, 247,  58],
#         [ 82,  51,  74]]], dtype=int32)

# %%
final_arr = np.split(a,2)
len(final_arr)
# Out:
# 2

# %%
plt.imshow(a)

# %%
plt.imshow(final_arr[1])

# %%
arr_1 = np.split(a,2,axis = 1)
arr_1
# Out:
# [array([[[131, 180, 204],
#          [ 34,  11, 180]],
#
#         [[ 58, 101,  85],
#          [159, 253, 188]],
#
#         [[169, 136,  91],
#          [252, 161, 104]],
#
#         [[ 85, 163,  54],
#          [ 95, 234, 125]]], dtype=int32),
#  array([[[197, 139, 199],
#          [ 74, 112, 189]],
#
#         [[233, 167,  35],
#          [153,  61,  32]],
#
#         [[ 19, 211, 163],
#          [254, 163, 194]],
#
#         [[ 61, 247,  58],
#          [ 82,  51,  74]]], dtype=int32)]

# %%
plt.imshow(arr_1[0])

# %%
arr_2 = np.split(a,3,axis = 2)
arr_2
# Out:
# [array([[[131],
#          [ 34],
#          [197],
#          [ 74]],
#
#         [[ 58],
#          [159],
#          [233],
#          [153]],
#
#         [[169],
#          [252],
#          [ 19],
#          [254]],
#
#         [[ 85],
#          [ 95],
#          [ 61],
#          [ 82]]], dtype=int32),
#  array([[[180],
#          [ 11],
#          [139],
#          [112]],
#
#         [[101],
#          [253],
#          [167],
#          [ 61]],
#
#         [[136],
#          [161],
#          [211],
#          [163]],
#
#         [[163],
#          [234],
#          [247],
#          [ 51]]], dtype=int32),
#  array([[[204],
#          [180],
#          [199],
#          [189]],
#
#         [[ 85],
#          [188],
#          [ 35],
#          [ 32]],
#
#         [[ 91],
#          [104],
#          [163],
#          [194]],
#
#         [[ 54],
#          [125],
#          [ 58],
#          [ 74]]], dtype=int32)]

# %%
plt.imshow(arr_2[0])

# %%
plt.imshow(a)

# %%
plt.imshow(np.split(a_arr,3,axis = 2)[1])

# %%
plt.imshow(np.split(a_arr,2)[0])

# %%
plt.imshow(np.split(a_arr,2,axis = 1)[1])

# %%
a_arr.shape
# Out:
# (700, 1920, 3)

# %%
1920//7
# Out:
# 274

# %%
plt.imshow(a_arr[:,274*5:,:])

# %%
plt.imshow(a_arr)

# %%
plt.imshow(a_arr[260:380,790:1130,:])

# %%
a = np.random.randint(1,500,(4,4))
a
# Out:
# array([[310,  33,  55, 101],
#        [392, 403, 475, 412],
#        [ 82, 444, 405, 399],
#        [ 80, 465, 290, 191]], dtype=int32)

# %%
np.where(a>200,'High sales',a)
# Out:
# array([['High sales', '33', '55', '101'],
#        ['High sales', 'High sales', 'High sales', 'High sales'],
#        ['82', 'High sales', 'High sales', 'High sales'],
#        ['80', 'High sales', 'High sales', '191']], dtype='<U11')

# %%
np.clip(a,100,300) #outliers remove/replace
# Out:
# array([[300, 100, 100, 101],
#        [300, 300, 300, 300],
#        [100, 300, 300, 300],
#        [100, 300, 290, 191]], dtype=int32)

# %%
# BROADCASTING

# %%
a = np.random.randint(1,10,(1,8))
b = np.random.randint(1,10,(8,1))
print(a)
print('*****************************************')
print(b)
# Out:
# [[4 2 8 5 1 4 5 3]]
# *****************************************
# [[3]
#  [3]
#  [9]
#  [8]
#  [6]
#  [1]
#  [2]
#  [5]]

# %%
a*b
# Out:
# array([[12,  6, 24, 15,  3, 12, 15,  9],
#        [12,  6, 24, 15,  3, 12, 15,  9],
#        [36, 18, 72, 45,  9, 36, 45, 27],
#        [32, 16, 64, 40,  8, 32, 40, 24],
#        [24, 12, 48, 30,  6, 24, 30, 18],
#        [ 4,  2,  8,  5,  1,  4,  5,  3],
#        [ 8,  4, 16, 10,  2,  8, 10,  6],
#        [20, 10, 40, 25,  5, 20, 25, 15]], dtype=int32)

# %%
# DATA Science
#data: Explore (Exploratary data analysis)
#EDA

# %%
#PANDAS: help to manipulate the data in tabular form
# maily helps in data analysis

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
import pandas as pd
import random
import numpy as np
products = ['Chair','Tables','Laptop','Mobile Phones','Charger']
region = ['East','West','North','South']
data = {'Order_id': range(1,1001),
        'Region name' : random.choices(region,k = 1000),
        'Product name': random.choices(products,k = 1000),
       'Sales': np.random.randint(100,10000,1000),
       'Quantity': np.random.randint(1,10,1000),
       'Profit': np.random.randint(-10000,10000,1000),
       'Date':random.choices(pd.date_range('01-01-2025','23-07-2025'),k =1000)}

table = pd.DataFrame(data)
table
# Out:
#      Order_id Region name   Product name  Sales  Quantity  Profit       Date
# 0           1       North        Charger   2065         5    -878 2025-06-30
# 1           2        East  Mobile Phones   2990         3   -5809 2025-01-05
# 2           3        West  Mobile Phones   4520         4    1683 2025-03-13
# 3           4        East         Tables   5968         3    2422 2025-06-20
# 4           5       North  Mobile Phones    550         8   -6127 2025-05-31
# ..        ...         ...            ...    ...       ...     ...        ...
# 995       996        West          Chair   7955         9   -1602 2025-02-02
# 996       997       North        Charger   7417         2    9834 2025-02-06
# 997       998        West         Laptop   1260         1   -6778 2025-05-20
# 998       999        West        Charger   5035         2    1118 2025-05-02
# 999      1000       North         Tables   4753         2   -9165 2025-05-20
#
# [1000 rows x 7 columns]

# %%
#TOP data
table.head(10) # by default it shows 5 data
# Out:
#    Order_id Region name   Product name  Sales  Quantity  Profit       Date
# 0         1       North        Charger   2065         5    -878 2025-06-30
# 1         2        East  Mobile Phones   2990         3   -5809 2025-01-05
# 2         3        West  Mobile Phones   4520         4    1683 2025-03-13
# 3         4        East         Tables   5968         3    2422 2025-06-20
# 4         5       North  Mobile Phones    550         8   -6127 2025-05-31
# 5         6        West         Tables   2701         5   -6550 2025-04-19
# 6         7       South  Mobile Phones   1282         5    4576 2025-02-28
# 7         8       North          Chair   4282         9   -6988 2025-02-03
# 8         9        West          Chair   2067         5   -3105 2025-07-06
# 9        10        West        Charger   6685         4   -3368 2025-03-20

# %%
table.tail()
# Out:
#      Order_id Region name Product name  Sales  Quantity  Profit       Date
# 995       996        West        Chair   7955         9   -1602 2025-02-02
# 996       997       North      Charger   7417         2    9834 2025-02-06
# 997       998        West       Laptop   1260         1   -6778 2025-05-20
# 998       999        West      Charger   5035         2    1118 2025-05-02
# 999      1000       North       Tables   4753         2   -9165 2025-05-20

# %%
table.sample(5)
# Out:
#      Order_id Region name   Product name  Sales  Quantity  Profit       Date
# 798       799       North         Tables   3216         9    8862 2025-06-10
# 598       599       South          Chair   5723         9    -903 2025-06-23
# 152       153        East        Charger   5975         7   -6283 2025-02-18
# 268       269        East         Laptop   9438         2    4963 2025-04-04
# 233       234        West  Mobile Phones   4348         5   -2702 2025-04-28

# %%
#info: about dataset
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_id      1000 non-null   int64
#  1   Region name   1000 non-null   object
#  2   Product name  1000 non-null   object
#  3   Sales         1000 non-null   int32
#  4   Quantity      1000 non-null   int32
#  5   Profit        1000 non-null   int32
#  6   Date          1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
# pandas has two data types: series, dataframe

# %%
table.columns
# Out:
# Index(['Order_id', 'Region name', 'Product name', 'Sales', 'Quantity',
#        'Profit', 'Date'],
#       dtype='object')

# %%
table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#isna()/isnull(): it will check the null values
table.isna().value_counts()
# Out:
# Order_id  Region name  Product name  Sales  Quantity  Profit  Date
# False     False        False         False  False     False   False    1000
# Name: count, dtype: int64
